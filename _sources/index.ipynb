# %% [markdown]
# # Boundary Element Methods in NGSolve
#
# Rafael Dorigo, TU Wien
#
# **NGSolve User Meeting 2026, June 29 – July 1, Winterthur**
#
# ## Topics
# * Boundary elements methods overview
# * Implementation details of BEM
# * Examples

# %% [markdown]
# <img src="NGSlogo.png" width="200" align="center">

# %% [markdown]
# ### Further documentation
# * NGSBem docs (Lucy Weggler): https://weggler.github.io/docu-ngsbem/intro.html
# * NGSolve docs: https://docu.ngsolve.org/latest/i-tutorials/index.html#boundary-element-and-fast-multipole-methods
