# %% [markdown]
# # Boundary Element Methods in NGSolve
#
# Rafael Dorigo, TU Wien
#
# **PDESoft 2026, July 13 – July 15, Vienna**
#
# ## Topics
#
# - Boundary integral operators and Galerkin discretization
# - Fast algorithms and implementation details
# - BEM Python API
# - Applications and examples

# %% [markdown]
# <img src="NGSlogo.png" width="200" align="center">

# %% [markdown]
# ### Documentation
#
# - [NGSBem documentation](https://weggler.github.io/docu-ngsbem/intro.html)
# - [NGSolve BEM and FMM tutorials](https://docu.ngsolve.org/latest/i-tutorials/index.html#boundary-element-and-fast-multipole-methods)
